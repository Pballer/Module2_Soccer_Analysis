# %%
import numpy as np
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('SoccerData/database.sqlite')
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'").fetchall()
# Out:
# [('sqlite_sequence',),
#  ('Matches',),
#  ('Teams_in_Matches',),
#  ('Teams',),
#  ('Unique_Teams',)]

# %%
cursor.execute("""PRAGMA table_info(FlatView_Advanced)""").fetchall()
# Out:
# [(0, 'Match_ID', 'INT', 0, None, 0),
#  (1, 'Unique_Team_ID', 'INT', 0, None, 0),
#  (2, 'Unique_Team', 'TEXT', 0, None, 0),
#  (3, 'Div', 'TEXT', 0, None, 0),
#  (4, 'Season', 'TEXT', 0, None, 0),
#  (5, 'Date', 'TEXT', 0, None, 0),
#  (6, 'HomeTeam', 'TEXT', 0, None, 0),
#  (7, 'AwayTeam', 'TEXT', 0, None, 0),
#  (8, 'FTHG', 'INT', 0, None, 0),
#  (9, 'FTAG', 'INT', 0, None, 0),
#  (10, 'FTR', 'TEXT', 0, None, 0),
#  (11, 'KaderHome', 'TEXT', 0, None, 0),
#  (12, 'AvgAgeHome', 'TEXT', 0, None, 0),
#  (13, 'ForeignPlayersHome', 'TEXT', 0, None, 0),
#  (14, 'OverallMarketValueHome', 'TEXT', 0, None, 0),
#  (15, 'AvgMarketValueHome', 'TEXT', 0, None, 0),
#  (16, 'StadiumCapacity', 'TEXT', 0, None, 0)]

# %% [markdown]
# We checked the VIEW command used to create the FlatView_Advanced joined table. But we would like to keep our data cleaning in python rather than sqlite so we created a large dataframe that has not been filtered down to the the 2011. This is to make sure that there are no errors between the 2011 label and the actual dates (5th of August, 2011 to the 5th of May, 2012) of the season. (https://en.wikipedia.org/wiki/2011%E2%80%9312_Bundesliga)

# %%
cursor.execute('''SELECT Match_ID,
                Unique_Team_ID, 
                Unique_Team, 
                Div, Season, 
                Date, 
                HomeTeam, 
                AwayTeam, 
                FTHG, 
                FTAG, 
                FTR 
                FROM FlatView_Advanced''')
all_variables_raw_unfiltered = pd.DataFrame(cursor.fetchall())
all_variables_raw_unfiltered.columns = [x[0] for x in cursor.description]
all_variables_raw_unfiltered.head()
# Out:
#    Match_ID  Unique_Team_ID    Unique_Team Div Season        Date  \
# 0      5772               1  Bayern Munich  D1   2005  2005-08-05
# 1      5378               1  Bayern Munich  D1   2005  2005-08-13
# 2      5693               1  Bayern Munich  D1   2005  2005-08-27
# 3      5386               1  Bayern Munich  D1   2005  2005-09-10
# 4      5661               1  Bayern Munich  D1   2005  2005-09-17
#
#         HomeTeam       AwayTeam  FTHG  FTAG FTR
# 0  Bayern Munich     M'gladbach     3     0   H
# 1     Leverkusen  Bayern Munich     2     5   A
# 2  Bayern Munich         Hertha     3     0   H
# 3       Nurnberg  Bayern Munich     1     2   A
# 4  Bayern Munich       Hannover     1     0   H

# %%
all_variables_raw_unfiltered.Date = pd.to_datetime(all_variables_raw_unfiltered.Date)

# %%
all_variables_raw_unfiltered[all_variables_raw_unfiltered['Season'] == '2011'].Date.describe().T
# Out:
# count                    1224
# unique                    136
# top       2012-04-07 00:00:00
# freq                       20
# first     2011-07-15 00:00:00
# last      2012-05-06 00:00:00
# Name: Date, dtype: object

# %%
all_variables_filtered = all_variables_raw_unfiltered.loc[((all_variables_raw_unfiltered.Div == 'D1')
                                 |(all_variables_raw_unfiltered.Div == 'D2')) 
                                 & (all_variables_raw_unfiltered.Season == '2011')]
all_variables_filtered
# Out:
#        Match_ID  Unique_Team_ID    Unique_Team Div Season       Date  \
# 204        1491               1  Bayern Munich  D1   2011 2011-08-07
# 205        1094               1  Bayern Munich  D1   2011 2011-08-13
# 14697      1665              44  Frankfurt FSV  D2   2011 2012-04-29
# 14698      1135              44  Frankfurt FSV  D2   2011 2012-05-06
#
#                  HomeTeam            AwayTeam  FTHG  FTAG FTR
# 204         Bayern Munich          M'gladbach     0     1   A
# 205             Wolfsburg       Bayern Munich     0     1   A
# 206         Bayern Munich             Hamburg     5     0   H
# 207        Kaiserslautern       Bayern Munich     0     3   A
# 208         Bayern Munich            Freiburg     7     0   H
# 209            Schalke 04       Bayern Munich     0     2   A
# 210         Bayern Munich          Leverkusen     3     0   H
# 211            Hoffenheim       Bayern Munich     0     0   D
# 212         Bayern Munich              Hertha     4     0   H
# 213              Hannover       Bayern Munich     2     1   H
# 214         Bayern Munich            Nurnberg     4     0   H
# 215              Augsburg       Bayern Munich     1     2   A
# 216         Bayern Munich            Dortmund     0     1   A
# 217                 Mainz       Bayern Munich     3     2   H
# 218         Bayern Munich       Werder Bremen     4     1   H
# 219             Stuttgart       Bayern Munich     1     2   A
# 220         Bayern Munich             FC Koln     3     0   H
# 221            M'gladbach       Bayern Munich     3     1   H
# 222         Bayern Munich           Wolfsburg     2     0   H
# 223               Hamburg       Bayern Munich     1     1   D
# 224         Bayern Munich      Kaiserslautern     2     0   H
# 225              Freiburg       Bayern Munich     0     0   D
# 226         Bayern Munich          Schalke 04     2     0   H
# 227            Leverkusen       Bayern Munich     2     0   H
# 228         Bayern Munich          Hoffenheim     7     1   H
# 229                Hertha       Bayern Munich     0     6   A
# 230         Bayern Munich            Hannover     2     1   H
# 231              Nurnberg       Bayern Munich     0     1   A
# 232         Bayern Munich            Augsburg     2     1   H
# 233              Dortmund       Bayern Munich     1     0   H
# ...                   ...                 ...   ...   ...  ..
# 14669       Frankfurt FSV       Ein Frankfurt     0     4   A
# 14670           Karlsruhe       Frankfurt FSV     0     4   A
# 14671       Frankfurt FSV      Erzgebirge Aue     1     1   D
# 14672         Munich 1860       Frankfurt FSV     4     0   H
# 14673       Frankfurt FSV        Braunschweig     1     1   D
# 14674              Aachen       Frankfurt FSV     1     3   A
# 14675       Frankfurt FSV             Cottbus     0     1   A
# 14676            St Pauli       Frankfurt FSV     2     1   H
# 14677       Frankfurt FSV  Fortuna Dusseldorf     2     5   A
# 14678       Frankfurt FSV       Hansa Rostock     0     0   D
# 14679      Greuther Furth       Frankfurt FSV     4     0   H
# 14680       Frankfurt FSV           Paderborn     2     2   D
# 14681             Dresden       Frankfurt FSV     2     2   D
# 14682        Union Berlin       Frankfurt FSV     4     0   H
# 14683       Frankfurt FSV              Bochum     0     2   A
# 14684            Duisburg       Frankfurt FSV     1     2   A
# 14685       Frankfurt FSV          Ingolstadt     1     1   D
# 14686       Ein Frankfurt       Frankfurt FSV     6     1   H
# 14687       Frankfurt FSV           Karlsruhe     2     1   H
# 14688      Erzgebirge Aue       Frankfurt FSV     4     3   H
# 14689       Frankfurt FSV         Munich 1860     3     1   H
# 14690        Braunschweig       Frankfurt FSV     0     0   D
# 14691       Frankfurt FSV              Aachen     2     1   H
# 14692             Cottbus       Frankfurt FSV     1     1   D
# 14693       Frankfurt FSV            St Pauli     3     3   D
# 14694  Fortuna Dusseldorf       Frankfurt FSV     1     0   H
# 14695       Hansa Rostock       Frankfurt FSV     0     5   A
# 14696       Frankfurt FSV      Greuther Furth     1     1   D
# 14697           Paderborn       Frankfurt FSV     1     0   H
# 14698       Frankfurt FSV             Dresden     1     1   D
#
# [1224 rows x 11 columns]

# %%
# all dates needed from DarkSky
dates_of_2011_season_div1_and_div2 = sorted(
    all_variables_filtered.Date.unique())
